# %%
import os
from ultralytics import YOLO
import cv2

# %%
model = YOLO(r'C:\Users\BM MONEY\runs\detect\train7\weights\best.pt')

# %%
video_path = 'videoplayback.mp4'

# %%
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise FileNotFoundError(f"Could not open video: {video_path}")

# %%
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
output_path = 'output_video.mp4'
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# %%
# Track objects with IDs
no_helmet_ids = set()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Run inference with tracking
    results = model.track(frame, conf=0.25, tracker="botsort.yaml", persist=True)
    
    # Create a copy of the frame for custom annotations
    annotated_frame = frame.copy()
    
    # Update no-helmet IDs
    current_no_helmet_ids = set()
    for box in results[0].boxes:
        cls = int(box.cls)
        conf = float(box.conf)
        track_id = int(box.id) if box.id is not None else None
        if track_id is None:
            continue
        
        # Get original head bounding box
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        
        # Expand bounding box to cover body
        head_width = x2 - x1
        head_height = y2 - y1
        
        # Assume body is ~3-4x head height downward and 2x head width
        body_height = int(head_height * 4)
        body_width = int(head_width * 2)
        
        # New coordinates
        new_x1 = max(0, x1 - head_width // 2)  # Extend left
        new_x2 = min(width, x2 + head_width // 2)  # Extend right
        new_y1 = max(0, y1)  # Keep top at head
        new_y2 = min(height, y1 + body_height)  # Extend downward
        
        # Draw expanded bounding box
        color = (0, 255, 0) if cls == 0 else (0, 0, 255)  # Green for With Helmet, Red for Without Helmet
        cv2.rectangle(annotated_frame, (new_x1, new_y1), (new_x2, new_y2), color, 2)
        cv2.putText(annotated_frame, f"ID: {track_id} {'No Helmet' if cls == 1 else 'Helmet'}", 
                    (new_x1, new_y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        
        # Handle non-helmeted bikers
        if cls == 1 and conf > 0.5:
            print(f"Person without helmet detected! Track ID: {track_id}")
            current_no_helmet_ids.add(track_id)
            
            # Draw red block (filled rectangle) over the body
            red_block_alpha = 0.4  # Transparency for red block
            overlay = annotated_frame.copy()
            cv2.rectangle(overlay, (new_x1, new_y1), (new_x2, new_y2), (0, 0, 255), -1)  # Filled red
            cv2.addWeighted(overlay, red_block_alpha, annotated_frame, 1 - red_block_alpha, 0, annotated_frame)
    
    # Update no_helmet_ids
    no_helmet_ids = no_helmet_ids & current_no_helmet_ids
    no_helmet_ids.update(current_no_helmet_ids)
    
    # Global warning for non-helmeted bikers
    if no_helmet_ids:
        cv2.putText(annotated_frame, "No Helmet Detected!", (50, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # Write frame to output video
    out.write(annotated_frame)
    
    # Display frame
    cv2.imshow('Helmet Detection', annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
print(f"Output video saved at: {output_path}")
# Out:
# 0: 384x640 1 With Helmet, 1 Without Helmet, 60.6ms
# Speed: 5.7ms preprocess, 60.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 58.7ms
# Speed: 5.5ms preprocess, 58.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 With Helmets, 28.0ms
# Speed: 3.0ms preprocess, 28.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 27.8ms
# Speed: 3.4ms preprocess, 27.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 27.8ms
# Speed: 3.0ms preprocess, 27.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 27.9ms
# Speed: 3.2ms preprocess, 27.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.8ms
# Speed: 2.8ms preprocess, 27.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.9ms
# Speed: 2.8ms preprocess, 27.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 27
ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 20.5ms
# Speed: 1.8ms preprocess, 20.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 24.6ms
# Speed: 1.8ms preprocess, 24.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 2 Without Helmets, 26.8ms
# Speed: 2.3ms preprocess, 26.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 2 Without Helmets, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 21.4ms
# Speed: 2.0ms preprocess, 21.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 25.5ms
# Speed: 2.1ms preprocess, 25.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 25.3ms
# Speed: 1.9ms preprocess, 25.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 20.8ms
# Speed: 1.7ms preprocess, 20.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 27.7ms
# Speed: 1.9ms preprocess, 27.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.9ms
# Speed: 2.4ms preprocess, 22.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 24.7ms
# Speed: 1.8ms preprocess, 24.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 26.7ms
# Speed: 2.2ms preprocess, 26.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 22.6ms
# Speed: 2.0ms preprocess, 22.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 19.5ms
# Speed: 1.9ms preprocess, 19.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 25.6ms
# Speed: 2.2ms preprocess, 25.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.8ms
# Speed: 2.1ms preprocess, 31.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 1.7ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 23.7ms
# Speed: 1.8ms preprocess, 23.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.5ms
# Speed: 1.6ms preprocess, 22.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.4ms
# Speed: 2.3ms preprocess, 22.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 20.7ms
# Speed: 2.3ms preprocess, 20.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 18.3ms
# Speed: 1.7ms preprocess, 18.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 19.0ms
# Speed: 2.2ms preprocess, 19.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.9ms
# Speed: 1.7ms preprocess, 22.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 25.8ms
# Speed: 2.5ms preprocess, 25.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 2 Without Helmets, 19.4ms
# Speed: 1.6ms preprocess, 19.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 21.1ms
# Speed: 2.1ms preprocess, 21.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 25.1ms
# Speed: 1.8ms preprocess, 25.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 29.6ms
# Speed: 2.5ms preprocess, 29.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 50.1ms
# Speed: 2.3ms preprocess, 50.1ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 1 Without Helmet, 21.5ms
# Speed: 2.2ms preprocess, 21.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 23.8ms
# Speed: 1.9ms preprocess, 23.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 33.1ms
# Speed: 2.4ms preprocess, 33.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 2 Without Helmets, 33.3ms
# Speed: 3.5ms preprocess, 33.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 2 Without Helmets, 33.1ms
# Speed: 3.6ms preprocess, 33.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 32.6ms
# Speed: 3.4ms preprocess, 32.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 32.3ms
# Speed: 4.0ms preprocess, 32.3ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 32.3ms
# Speed: 2.9ms preprocess, 32.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 32.3ms
# Speed: 3.6ms preprocess, 32.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 35.5ms
# Speed: 3.2ms preprocess, 35.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 35.0ms
# Speed: 3.2ms preprocess, 35.0ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 30.8ms
# Speed: 3.3ms preprocess, 30.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 30.6ms
# Speed: 3.5ms preprocess, 30.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 30.6ms
# Speed: 3.1ms preprocess, 30.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 30.7ms
# Speed: 2.8ms preprocess, 30.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 30.7ms
# Speed: 3.1ms preprocess, 30.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 31.1ms
# Speed: 3.0ms preprocess, 31.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 30.6ms
# Speed: 3.5ms preprocess, 30.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 30.4ms
# Speed: 3.1ms preprocess, 30.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 30.4ms
# Speed: 3.1ms preprocess, 30.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 With Helmets, 29.1ms
# Speed: 2.7ms preprocess, 29.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 29.2ms
# Speed: 2.7ms preprocess, 29.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 30.0ms
# Speed: 2.9ms preprocess, 30.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 37.7ms
# Speed: 3.0ms preprocess, 37.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 34.8ms
# Speed: 3.0ms preprocess, 34.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 29.3ms
# ...
# Speed: 2.1ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 369
#
# 0: 384x640 3 Without Helmets, 22.7ms
# Speed: 1.9ms preprocess, 22.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 369
#
# 0: 384x640 3 Without Helmets, 22.1ms
# Speed: 1.9ms preprocess, 22.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Without Helmets, 19.4ms
# Speed: 1.9ms preprocess, 19.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 20.9ms
# Speed: 2.8ms preprocess, 20.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 21.4ms
# Speed: 3.0ms preprocess, 21.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 21.2ms
# Speed: 3.2ms preprocess, 21.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 19.9ms
# Speed: 1.9ms preprocess, 19.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.3ms
# Speed: 1.7ms preprocess, 22.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 22.6ms
# Speed: 2.4ms preprocess, 22.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 27.5ms
# Speed: 1.9ms preprocess, 27.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 2 Without Helmets, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 18.3ms
# Speed: 2.3ms preprocess, 18.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 2 With Helmets, 1 Without Helmet, 19.6ms
# Speed: 2.2ms preprocess, 19.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 1 Without Helmet, 24.9ms
# Speed: 2.1ms preprocess, 24.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 387
#
# 0: 384x640 3 Without Helmets, 22.2ms
# Speed: 1.9ms preprocess, 22.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 21.9ms
# Speed: 2.3ms preprocess, 21.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 23.7ms
# Speed: 2.1ms preprocess, 23.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 32.9ms
# Speed: 3.3ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 33.0ms
# Speed: 3.3ms preprocess, 33.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 33.0ms
# Speed: 3.6ms preprocess, 33.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 32.8ms
# Speed: 3.0ms preprocess, 32.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 32.9ms
# Speed: 2.9ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 30.7ms
# Speed: 2.8ms preprocess, 30.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 34.5ms
# Speed: 3.8ms preprocess, 34.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 30.8ms
# Speed: 3.1ms preprocess, 30.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 30.7ms
# Speed: 3.0ms preprocess, 30.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 30.7ms
# Speed: 3.3ms preprocess, 30.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.7ms
# Speed: 2.9ms preprocess, 29.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 29.6ms
# Speed: 2.8ms preprocess, 29.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 29.7ms
# Speed: 2.9ms preprocess, 29.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.1ms
# Speed: 2.8ms preprocess, 29.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.8ms
# Speed: 2.5ms preprocess, 28.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 29.0ms
# Speed: 3.2ms preprocess, 29.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 28.3ms
# Speed: 2.9ms preprocess, 28.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 32.4ms
# Speed: 3.6ms preprocess, 32.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.4ms
# Speed: 2.9ms preprocess, 28.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.4ms
# Speed: 2.5ms preprocess, 28.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 28.4ms
# Speed: 3.2ms preprocess, 28.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.0ms
# Speed: 2.6ms preprocess, 28.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 33.3ms
# Speed: 3.3ms preprocess, 33.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 27.9ms
# Speed: 3.4ms preprocess, 27.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.0ms
# Speed: 2.9ms preprocess, 28.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 366
#
# 0: 384x640 1 Without Helmet, 27.9ms
# Speed: 2.9ms preprocess, 27.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 1 Without Helmet, 27.8ms
# Speed: 3.1ms preprocess, 27.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 27.9ms
# Speed: 3.2ms preprocess, 27.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 27.9ms
# Speed: 3.3ms preprocess, 27.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 27.7ms
# Speed: 3.1ms preprocess, 27.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 27.8ms
# Speed: 3.2ms preprocess, 27.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 27.9ms
# Speed: 3.3ms preprocess, 27.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 27.8ms
# Speed: 3.2ms preprocess, 27.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 27.6ms
# Speed: 2.5ms preprocess, 27.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.6ms
# Speed: 3.2ms preprocess, 27.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.6ms
# Speed: 3.2ms preprocess, 27.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 27.7ms
# Speed: 3.4ms preprocess, 27.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 27.4ms
# Speed: 2.9ms preprocess, 27.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Without Helmets, 27.6ms
# Speed: 3.0ms preprocess, 27.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 28.9ms
# Speed: 3.7ms preprocess, 28.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Person without helmet detected! Track ID: 422
#
# 0: 384x640 1 Without Helmet, 27.5ms
# Speed: 3.2ms preprocess, 27.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 1 Without Helmet, 26.9ms
# Speed: 2.9ms preprocess, 26.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 26.8ms
# Speed: 2.8ms preprocess, 26.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 26.9ms
# Speed: 2.5ms preprocess, 26.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 27.1ms
# Speed: 2.8ms preprocess, 27.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 26.7ms
# Speed: 2.9ms preprocess, 26.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 26.8ms
# Speed: 3.1ms preprocess, 26.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 2.8ms preprocess, 26.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 1.7ms preprocess, 25.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 21.8ms
# Speed: 1.9ms preprocess, 21.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.8ms preprocess, 24.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 2.1ms preprocess, 42.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.7ms
# Speed: 1.6ms preprocess, 27.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.9ms
# Speed: 2.1ms preprocess, 28.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 25.1ms
# Speed: 2.2ms preprocess, 25.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.6ms preprocess, 43.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 19.1ms
# Speed: 1.5ms preprocess, 19.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.7ms
# Speed: 2.2ms preprocess, 26.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 1.9ms preprocess, 26.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 23.2ms
# Speed: 1.5ms preprocess, 23.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.9ms
# Speed: 1.5ms preprocess, 20.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.6ms preprocess, 25.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 1.6ms preprocess, 25.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 22.5ms
# Speed: 1.6ms preprocess, 22.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 2.2ms preprocess, 26.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 34.6ms
# Speed: 1.8ms preprocess, 34.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 31.2ms
# Speed: 2.4ms preprocess, 31.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.5ms
# Speed: 2.1ms preprocess, 28.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 24.4ms
# Speed: 2.5ms preprocess, 24.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 22.5ms
# Speed: 2.3ms preprocess, 22.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 29.0ms
# Speed: 2.9ms preprocess, 29.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 29.1ms
# Speed: 3.1ms preprocess, 29.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Without Helmets, 29.0ms
# Speed: 2.9ms preprocess, 29.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 2 Without Helmets, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 29.0ms
# Speed: 2.8ms preprocess, 29.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.1ms
# Speed: 3.5ms preprocess, 28.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.2ms
# Speed: 2.9ms preprocess, 28.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 28.5ms
# Speed: 2.9ms preprocess, 28.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Without Helmet, 29.4ms
# Speed: 3.1ms preprocess, 29.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.2ms
# Speed: 3.0ms preprocess, 28.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.1ms
# Speed: 3.0ms preprocess, 28.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.0ms
# Speed: 2.9ms preprocess, 28.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.5ms
# Speed: 3.0ms preprocess, 27.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 35.3ms
# Speed: 3.4ms preprocess, 35.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 With Helmet, 27.8ms
# Speed: 3.5ms preprocess, 27.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 With Helmets, 1 Without Helmet, 27.7ms
# Speed: 3.1ms preprocess, 27.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Output video saved at: output_video.mp4
